# %%
import pandas as pd
df=pd.read_csv('data/raw/bank/bank-.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  str
#  2   marital    45211 non-null  str
#  3   education  45209 non-null  str
#  4   default    45208 non-null  str
#  5   balance    45210 non-null  float64
#  6   housing    45211 non-null  str
#  7   loan       45211 non-null  str
#  8   contact    45211 non-null  str
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  str
#  11  duration   45210 non-null  float64
#  12  campaign   45211 non-null  int64
#  13  pdays      45203 non-null  float64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  str
#  16  Target     45205 non-null  str
# dtypes: float64(3), int64(4), str(10)
# memory usage: 5.9 MB

# %%
df.head()
# Out:
#    age           job  marital  education  ... pdays  previous poutcome Target
# 0   58    management  married   tertiary  ...  -1.0         0  unknown     no
# 1   44    technician   single  secondary  ...  -1.0         0  unknown     no
# 2   33  entrepreneur  married  secondary  ...  -1.0         0  unknown     no
# 3   47   blue-collar  married    unknown  ...  -1.0         0  unknown     no
# 4   33       unknown   single    unknown  ...  -1.0         0  unknown     no
#
# [5 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    2
# default      3
# balance      1
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     1
# campaign     0
# pdays        8
# previous     0
# poutcome     0
# Target       6
# dtype: int64

# %%
#missing value
def toldir(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='str':
                df.fillna({col:df[col].mode()[0]},inplace=True)
            else:
                df.fillna({col:df[col].mean()},inplace=True)
    return df

# %%
df=toldir(df)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  str
#  2   marital    45211 non-null  str
#  3   education  45211 non-null  str
#  4   default    45211 non-null  str
#  5   balance    45211 non-null  float64
#  6   housing    45211 non-null  str
#  7   loan       45211 non-null  str
#  8   contact    45211 non-null  str
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  str
#  11  duration   45211 non-null  float64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  float64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  str
#  16  Target     45211 non-null  str
# dtypes: float64(3), int64(4), str(10)
# memory usage: 5.9 MB

# %%
df.isnull().any()
# Out:
# age          False
# job          False
# marital      False
# education    False
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day          False
# month        False
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# Target       False
# dtype: bool

# %%
df.nunique()
# Out:
# age            77
# job            12
# marital         3
# education       4
# default         2
# balance      7169
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1574
# campaign       48
# pdays         560
# previous       41
# poutcome        4
# Target          2
# dtype: int64

# %%
#Encoding
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
encoder=LabelEncoder()
def encodla(df):
    for col in df.columns:
        if df[col].dtype=='str':
            if df[col].nunique()<=3:
                dummies=pd.get_dummies(df[col],prefix=col,dtype=int)
                df=pd.concat([df.drop(columns=col),dummies],axis=1)
            else:
                df[col]=encoder.fit_transform(df[col])
    return df

# %%
df=encodla(df)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                45211 non-null  int64
#  1   job                45211 non-null  int64
#  2   education          45211 non-null  int64
#  3   balance            45211 non-null  float64
#  4   day                45211 non-null  int64
#  5   month              45211 non-null  int64
#  6   duration           45211 non-null  float64
#  7   campaign           45211 non-null  int64
#  8   pdays              45211 non-null  float64
#  9   previous           45211 non-null  int64
#  10  poutcome           45211 non-null  int64
#  11  marital_divorced   45211 non-null  int64
#  12  marital_married    45211 non-null  int64
#  13  marital_single     45211 non-null  int64
#  14  default_no         45211 non-null  int64
#  15  default_yes        45211 non-null  int64
# ...

# %%
#Scaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
num_col=df.select_dtypes(include=['int64','float64']).columns.drop('age')
def scaling(df):

    df[num_col]=scaler.fit_transform(df[num_col])
    return df

# %%
df=scaling(df)
df.head()
# Out:
#    age       job  education  ...  contact_unknown  Target_no  Target_yes
# 0   58  0.363636   0.666667  ...              1.0        1.0         0.0
# 1   44  0.818182   0.333333  ...              1.0        1.0         0.0
# 2   33  0.181818   0.333333  ...              1.0        1.0         0.0
# 3   47  0.090909   1.000000  ...              1.0        1.0         0.0
# 4   33  1.000000   1.000000  ...              1.0        1.0         0.0
#
# [5 rows x 25 columns]

# %% [markdown]
# # Linear Regression

# %%
#Model selection
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
#Training
x=df.drop('age',axis=1)

# %%
y=df['age']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (36168, 24)

# %%
y_train.shape
# Out:
# (36168,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Prediction
y_pred=lr.predict(x_test)
y_pred[0]
# Out:
# np.float64(41.71457724993818)

# %%
#Evaluation
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)

# %%
print('r2: ',r2)
print('mae: ',mae)
print('mse: ',mse)
# Out:
# r2:  0.2590053545424218
# mae:  7.340611158759769
# mse:  83.57743284957434

# %% [markdown]
# # Lasso Regression

# %%
df=pd.read_csv('data/raw/bank/bank-.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  str
#  2   marital    45211 non-null  str
#  3   education  45209 non-null  str
#  4   default    45208 non-null  str
#  5   balance    45210 non-null  float64
#  6   housing    45211 non-null  str
#  7   loan       45211 non-null  str
#  8   contact    45211 non-null  str
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  str
#  11  duration   45210 non-null  float64
#  12  campaign   45211 non-null  int64
#  13  pdays      45203 non-null  float64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  str
#  16  Target     45205 non-null  str
# dtypes: float64(3), int64(4), str(10)
# memory usage: 5.9 MB

# %%
toldir(df)
# Out:
#        age           job   marital  education  ...  pdays  previous poutcome Target
# 0       58    management   married   tertiary  ...   -1.0         0  unknown     no
# 1       44    technician    single  secondary  ...   -1.0         0  unknown     no
# 2       33  entrepreneur   married  secondary  ...   -1.0         0  unknown     no
# 3       47   blue-collar   married    unknown  ...   -1.0         0  unknown     no
# 4       33       unknown    single    unknown  ...   -1.0         0  unknown     no
# ...    ...           ...       ...        ...  ...    ...       ...      ...    ...
# 45206   51    technician   married   tertiary  ...   -1.0         0  unknown    yes
# 45207   71       retired  divorced    primary  ...   -1.0         0  unknown    yes
# 45208   72       retired   married  secondary  ...  184.0         3  success    yes
# 45209   57   blue-collar   married  secondary  ...   -1.0         0  unknown     no
# ...

# %%
df=toldir(df)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  str
#  2   marital    45211 non-null  str
#  3   education  45211 non-null  str
#  4   default    45211 non-null  str
#  5   balance    45211 non-null  float64
#  6   housing    45211 non-null  str
#  7   loan       45211 non-null  str
#  8   contact    45211 non-null  str
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  str
#  11  duration   45211 non-null  float64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  float64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  str
#  16  Target     45211 non-null  str
# dtypes: float64(3), int64(4), str(10)
# memory usage: 5.9 MB

# %%
df=encodla(df)
df=scaling(df)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                45211 non-null  int64
#  1   job                45211 non-null  float64
#  2   education          45211 non-null  float64
#  3   balance            45211 non-null  float64
#  4   day                45211 non-null  float64
#  5   month              45211 non-null  float64
#  6   duration           45211 non-null  float64
#  7   campaign           45211 non-null  float64
#  8   pdays              45211 non-null  float64
#  9   previous           45211 non-null  float64
#  10  poutcome           45211 non-null  float64
#  11  marital_divorced   45211 non-null  float64
#  12  marital_married    45211 non-null  float64
#  13  marital_single     45211 non-null  float64
#  14  default_no         45211 non-null  float64
#  15  default_yes        45211 non-null  float64
# ...

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso(alpha=0.1)

# %%
x=df.drop('age',axis=1)

# %%
y=df['age']

# %%
from sklearn.model_selection import train_test_split

# %%
lasso
# Out:
# Lasso(alpha=0.1)

# %%
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_pred=lasso.predict(x_test)

# %%
#Evaluation
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)

# %%
print('r2: ',r2)
print('mae: ',mae)
print('mse: ',mse)
# Out:
# r2:  0.24657460802206566
# mae:  7.3993090982859115
# mse:  84.97950759997093

# %% [markdown]
# # Ridge Regression

# %%
df=pd.read_csv('data/raw/bank/bank-.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  str
#  2   marital    45211 non-null  str
#  3   education  45209 non-null  str
#  4   default    45208 non-null  str
#  5   balance    45210 non-null  float64
#  6   housing    45211 non-null  str
#  7   loan       45211 non-null  str
#  8   contact    45211 non-null  str
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  str
#  11  duration   45210 non-null  float64
#  12  campaign   45211 non-null  int64
#  13  pdays      45203 non-null  float64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  str
#  16  Target     45205 non-null  str
# dtypes: float64(3), int64(4), str(10)
# memory usage: 5.9 MB

# %%
df=toldir(df)
df=encodla(df)
df=scaling(df)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                45211 non-null  int64
#  1   job                45211 non-null  float64
#  2   education          45211 non-null  float64
#  3   balance            45211 non-null  float64
#  4   day                45211 non-null  float64
#  5   month              45211 non-null  float64
#  6   duration           45211 non-null  float64
#  7   campaign           45211 non-null  float64
#  8   pdays              45211 non-null  float64
#  9   previous           45211 non-null  float64
#  10  poutcome           45211 non-null  float64
#  11  marital_divorced   45211 non-null  float64
#  12  marital_married    45211 non-null  float64
#  13  marital_single     45211 non-null  float64
#  14  default_no         45211 non-null  float64
#  15  default_yes        45211 non-null  float64
# ...

# %%
from sklearn.linear_model import Ridge

# %%
ridge=Ridge(alpha=0.1)

# %%
x=df.drop('age',axis=1)

# %%
y=df['age']

# %%
from sklearn.model_selection import train_test_split

# %%
ridge
# Out:
# Ridge(alpha=0.1)

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.1)

# %%
y_pred=ridge.predict(x_test)

# %%
#Evaluation
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)

# %%
print('r2: ',r2)
print('mae: ',mae)
print('mse: ',mse)
# Out:
# r2:  0.25902024557910663
# mae:  7.340599049528066
# mse:  83.5757532765488

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# %%
x=df.drop('age',axis=1)

# %%
y=df['age']

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=rf.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)

# %%
print('r2: ',r2)
print('mae: ',mae)
print('mse: ',mse)
# Out:
# r2:  0.4322079222497448
# mae:  6.412718677430056
# mse:  64.0417640553774

# %% [markdown]
# # DecisionTree

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)

# %%
print('r2: ',r2)
print('mae: ',mae)
print('mse: ',mse)
# Out:
# r2:  -0.12257311350320377
# mae:  8.695676213645914
# mse:  126.61600132699326

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
kf=KFold(n_splits=10,shuffle=True,random_state=42)

# %%
scores=cross_val_score(lr,x,y,cv=kf,scoring='r2')

# %%
print(scores)
# Out:
# [0.2524531  0.2647834  0.25572956 0.25459937 0.2445712  0.25438132
#  0.26633674 0.25722798 0.25804221 0.26429526]

# %%
import numpy as np

# %%
np.mean(scores)
# Out:
# np.float64(0.2572420140098376)

# %%
np.std(scores)
# Out:
# np.float64(0.0062523038658864865)

# %% [markdown]
# # Tabulate

# %%
from tabulate import tabulate

# %%
results=[
    ['linear regression',0.2590,7.3406,83.5774],
    ['lasso regression', 0.24657,7.3993,84.9795],
    ['ridge regression', 0.25902,7.3405,83.5757],
    ['random forest', 0.4322,6.4127,64.0417],
    ['decisiontree', 0.1225,8.6956,126.616]
]
headers=['Algorithm','r2_score','mae','mse']
table=tabulate(results,headers=headers,tablefmt='grid')
print(table)
# Out:
# +-------------------+------------+--------+----------+
# | Algorithm         |   r2_score |    mae |      mse |
# +===================+============+========+==========+
# | linear regression |    0.259   | 7.3406 |  83.5774 |
# +-------------------+------------+--------+----------+
# | lasso regression  |    0.24657 | 7.3993 |  84.9795 |
# +-------------------+------------+--------+----------+
# | ridge regression  |    0.25902 | 7.3405 |  83.5757 |
# +-------------------+------------+--------+----------+
# | random forest     |    0.4322  | 6.4127 |  64.0417 |
# +-------------------+------------+--------+----------+
# | decisiontree      |    0.1225  | 8.6956 | 126.616  |
# +-------------------+------------+--------+----------+
