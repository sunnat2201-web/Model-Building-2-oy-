# %% [markdown]
# # Visualation

# %%
import pandas as pd
df=pd.read_csv('ecommerce_sales.csv')

# %%
df.head()
# Out:
#    order_id order_date  customer_id product_category region  quantity  \
# 0     10001   1/1/2022         1102           Beauty  South       7.0
# 1     10002   1/2/2022         1435         Clothing  South       7.0
# 2     10003   1/3/2022         1860           Beauty   East       3.0
# 3     10004   1/4/2022         1270      Electronics   West       5.0
# 4     10005   1/5/2022         1106         Clothing   West       5.0
#
#    unit_price  discount payment_method  delivery_days  customer_rating  \
# 0      373.65      0.28         Wallet           10.0              4.7
# 1       47.74      0.09           Card            6.0              3.9
# 2      311.28      0.31            COD            6.0              2.5
# 3      524.47      0.02         Wallet            6.0              1.6
# 4      139.87      0.33         Wallet            4.0              4.9
#
#    revenue
# 0  1883.20
# 1   304.10
# 2   644.35
# 3  2569.90
# 4   468.56

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   str
#  2   customer_id       5000 non-null   int64
#  3   product_category  4992 non-null   str
#  4   region            5000 non-null   str
#  5   quantity          4984 non-null   float64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   str
#  9   delivery_days     4989 non-null   float64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           4987 non-null   float64
# dtypes: float64(6), int64(2), str(4)
# memory usage: 468.9 KB

# %%
df.isnull().sum()
# Out:
# order_id             0
# order_date           0
# customer_id          0
# product_category     8
# region               0
# quantity            16
# unit_price           0
# discount             0
# payment_method       0
# delivery_days       11
# customer_rating      0
# revenue             13
# dtype: int64

# %%
#data preprocessing
def toldir(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=="str":
                df.fillna({col:df[col].mode()[0]},inplace=True)
            else:



                df.fillna({col:df[col].mean()},inplace=True)

    return (df)

# %%
df=toldir(df)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   str
#  2   customer_id       5000 non-null   int64
#  3   product_category  5000 non-null   str
#  4   region            5000 non-null   str
#  5   quantity          5000 non-null   float64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   str
#  9   delivery_days     5000 non-null   float64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           5000 non-null   float64
# dtypes: float64(6), int64(2), str(4)
# memory usage: 468.9 KB

# %%
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# customer_id         0
# product_category    0
# region              0
# quantity            0
# unit_price          0
# discount            0
# payment_method      0
# delivery_days       0
# customer_rating     0
# revenue             0
# dtype: int64

# %%
# Encoding
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df.nunique()
# Out:
# order_id            5000
# order_date          5000
# customer_id          989
# product_category       4
# region                 4
# quantity               8
# unit_price          4788
# discount              36
# payment_method         3
# delivery_days         12
# customer_rating       41
# revenue             4929
# dtype: int64

# %%
def encodla(df):
    for col in df.columns:
        if df[col].dtype=='str':
            df[col]=encoder.fit_transform(df[col])
    return df

# %%
encodla(df)
# Out:
#       order_id  order_date  customer_id  product_category  region  quantity  \
# 0        10001           0         1102                 0       2       7.0
# 1        10002         154         1435                 1       2       7.0
# 2        10003         308         1860                 0       0       3.0
# 3        10004         350         1270                 2       3       5.0
# 4        10005         364         1106                 1       3       5.0
# ...        ...         ...          ...               ...     ...       ...
# 4995     14996        4943         1289                 1       3       2.0
# 4996     14997        4957         1294                 0       1       3.0
# 4997     14998        4971         1450                 0       3       3.0
# 4998     14999        4985         1903                 2       2       4.0
# 4999     15000        4999         1214                 3       0       7.0
#
#       unit_price  discount  payment_method  delivery_days  customer_rating  \
# 0         373.65      0.28               2           10.0              4.7
# 1          47.74      0.09               1            6.0              3.9
# 2         311.28      0.31               0            6.0              2.5
# 3         524.47      0.02               2            6.0              1.6
# 4         139.87      0.33               2            4.0              4.9
# ...          ...       ...             ...            ...              ...
# 4995      371.74      0.27               0            3.0              2.3
# 4996      553.67      0.14               0           11.0              2.2
# 4997       77.22      0.24               2            6.0              3.4
# 4998      138.41      0.21               0            4.0              2.8
# 4999      231.58      0.34               0            5.0              3.9
#
#       revenue
# 0     1883.20
# 1      304.10
# 2      644.35
# 3     2569.90
# 4      468.56
# ...       ...
# 4995   542.74
# 4996  1428.47
# 4997   176.06
# 4998   437.38
# 4999  1069.90
#
# [5000 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   int64
#  2   customer_id       5000 non-null   int64
#  3   product_category  5000 non-null   int64
#  4   region            5000 non-null   int64
#  5   quantity          5000 non-null   float64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   int64
#  9   delivery_days     5000 non-null   float64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           5000 non-null   float64
# dtypes: float64(6), int64(6)
# memory usage: 468.9 KB

# %%
#pip install klib
# !pip install klib
# %pip install klib 
# %pip install klib
# Out:
# Requirement already satisfied: klib in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.4.1)
# Requirement already satisfied: jinja2>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from klib) (3.1.6)
# Requirement already satisfied: matplotlib>=3.9.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from klib) (3.11.1)
# Requirement already satisfied: numpy>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from klib) (2.4.4)
# Requirement already satisfied: pandas<4.0,>=1.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from klib) (3.0.2)
# Requirement already satisfied: plotly>=5.24.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from klib) (6.9.0)
# Requirement already satisfied: scipy>=1.14.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from klib) (1.17.1)
# Requirement already satisfied: screeninfo>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from klib) (0.8.1)
# Requirement already satisfied: seaborn>=0.13.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from klib) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sunnatabdurayimov/Library/Python/3.14/lib/python/site-packages (from pandas<4.0,>=1.4->klib) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jinja2>=3.1.0->klib) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.9.0->klib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.9.0->klib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.9.0->klib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.9.0->klib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/sunnatabdurayimov/Library/Python/3.14/lib/python/site-packages (from matplotlib>=3.9.0->klib) (26.2)
# Requirement already satisfied: pillow>=9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.9.0->klib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.9.0->klib) (3.3.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from plotly>=5.24.0->klib) (2.24.0)
# Requirement already satisfied: six>=1.5 in /Users/sunnatabdurayimov/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.4->klib) (1.17.0)
# Requirement already satisfied: Cython in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from screeninfo>=0.8.1->klib) (3.2.9)
# Requirement already satisfied: pyobjc-framework-Cocoa in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from screeninfo>=0.8.1->klib) (12.2.2)
# Requirement already satisfied: pyobjc-core>=12.2.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pyobjc-framework-Cocoa->screeninfo>=0.8.1->klib) (12.2.2)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df=pd.read_csv('ecommerce_sales.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   str
#  2   customer_id       5000 non-null   int64
#  3   product_category  4992 non-null   str
#  4   region            5000 non-null   str
#  5   quantity          4984 non-null   float64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   str
#  9   delivery_days     4989 non-null   float64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           4987 non-null   float64
# dtypes: float64(6), int64(2), str(4)
# memory usage: 468.9 KB

# %% [markdown]
# # Klib

# %%
import klib

# %%
klib.missingval_plot(df) #Tushurib qoldirilgan qiymatlarni visual korinishi
# Out:
# GridSpec(6, 6)
# findfont: Failed to find font weight light, now using 400.

# %%
klib.corr_interactive_plot(df) #Input qiymatlar muhimliligi

# %%
df=klib.data_cleaning(df) #datani tozalash
# Out:
# Shape of cleaned data: (5000, 12) - Remaining NAs: 48
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.27 MB (-58.7%)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int16
#  1   order_date        5000 non-null   string
#  2   customer_id       5000 non-null   int16
#  3   product_category  4992 non-null   category
#  4   region            5000 non-null   category
#  5   quantity          4984 non-null   float32
#  6   unit_price        5000 non-null   float32
#  7   discount          5000 non-null   float32
#  8   payment_method    5000 non-null   category
#  9   delivery_days     4989 non-null   float32
#  10  customer_rating   5000 non-null   float32
#  11  revenue           4987 non-null   float32
# dtypes: category(3), float32(6), int16(2), string(1)
# memory usage: 190.6 KB

# %% [markdown]
# # Datacleaner

# %%
import pandas as pd
df=pd.read_csv('ecommerce_sales.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   str
#  2   customer_id       5000 non-null   int64
#  3   product_category  4992 non-null   str
#  4   region            5000 non-null   str
#  5   quantity          4984 non-null   float64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   str
#  9   delivery_days     4989 non-null   float64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           4987 non-null   float64
# dtypes: float64(6), int64(2), str(4)
# memory usage: 468.9 KB

# %%
pip install datacleaner
# Out:
# Requirement already satisfied: datacleaner in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (0.1.5)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from datacleaner) (3.0.2)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from datacleaner) (1.8.0)
# Requirement already satisfied: update_checker in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from datacleaner) (1.0.0)
# Requirement already satisfied: numpy>=2.3.3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas->datacleaner) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sunnatabdurayimov/Library/Python/3.14/lib/python/site-packages (from pandas->datacleaner) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/sunnatabdurayimov/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->datacleaner) (1.17.0)
# Requirement already satisfied: scipy>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn->datacleaner) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn->datacleaner) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn->datacleaner) (3.6.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from datacleaner import autoclean

# %%
df=autoclean(df)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:77: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:83: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].mode()[0], inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:77: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:83: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].mode()[0], inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:77: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:77: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:77: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:83: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].mode()[0], inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:77: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:77: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/datacleaner/datacleaner.py:77: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   str
#  2   customer_id       5000 non-null   int64
#  3   product_category  4992 non-null   str
#  4   region            5000 non-null   str
#  5   quantity          4984 non-null   float64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   str
#  9   delivery_days     4989 non-null   float64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           4987 non-null   float64
# dtypes: float64(6), int64(2), str(4)
# memory usage: 468.9 KB
